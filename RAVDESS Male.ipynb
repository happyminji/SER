# %% [markdown]
# ## - STT로 생성된 텍스트 파일에 색상을 매핑

# %%
import csv

# 감정-색상 매핑 테이블
emotion_to_rgb = {
    "neutral": (30, 40, 30),
    "calm": (40, 255, 255),
    "happy": (210, 255, 10),
    "sad": (40, 0, 80),
    "angry": (255, 0, 0),
    "fearful": (127, 127, 127),
    "disgust": (0, 112, 192),
    "surprised": (180, 20, 0),   
    # 추가적인 감정과 RGB 값 매핑을 계속 추가할 수 있음
}
             
# CSV 파일 읽기
file_path = r'E:\9.21 ser\Emo-DB SER_0821\SER_Platform_AICS\datasets\RAVDESS_male\\Labelled_RAVDESS_male_AUDIO.csv'
with open(file_path, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        modality = row['modality']
        emotion = row['emotion']
        statement = row['statement']
        gender = row['gender']

        
        # 감정에 대응하는 색상 가져오기
        color = emotion_to_rgb.get(emotion, 'unknown')
        
        # 색상 정보를 포함한 텍스트 생성
        colored_text = f"modality: {modality}, Emotion: {emotion}, Statement: {statement}, Gender: {gender}, Color: {color}"
        
        # 생성된 텍스트를 파일에 추가
        with open('EMO_DB_male_output_text.txt', 'a') as korean_output_file:
            korean_output_file.write(colored_text + '\n')

print("색상 매핑이 완료되었습니다.")
# Out:
# 색상 매핑이 완료되었습니다.

# %%
# 필요한 라이브러리 가져오기
import numpy as np
import itertools
import matplotlib.pyplot as plt  # matplotlib 추가

# Project Level Imports
import datasource_analysis
import feature_extraction_audio
import io_operations
import model_creation_audio
import model_evaluation_audio
import config

# 감정 레이블을 RGB 값으로 매핑하는 함수 정의
def map_emotion_to_rgb(emotion):
    emotion_to_rgb = {
        "neutral": (30, 40, 30),
        "calm": (40, 255, 255),
        "happy": (210, 255, 10),
        "sad": (40, 0, 80),
        "angry": (255, 0, 0),
        "fearful": (127, 127, 127),
        "disgust": (0, 112, 192),
        "surprised": (180, 20, 0),  
        # 추가적인 감정과 RGB 값 매핑을 계속 추가할 수 있음
    }
    return emotion_to_rgb.get(emotion, (0, 0, 0))  # 기본값은 검은색

def show_emotion_images(dataDF):
    # 감정 레이블에 해당하는 RGB 값을 활용하여 색상 이미지를 생성하고 표시
    emotions = dataDF['emotion'].unique()
    fig, axs = plt.subplots(3, 4, figsize=(12, 8))

    for idx, emotion in enumerate(emotions):
        ax = axs[idx // 4, idx % 4]
        rgb = map_emotion_to_rgb(emotion)
        ax.imshow([[rgb]], extent=(0, 1, 0, 1))
        ax.set_title(emotion)
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# 감정의 강도를 추정하는 함수
def estimate_emotion_intensity(predicted_emotion, model_accuracy):
    # 감정 강도 추정 방식을 정의합니다
    estimated_intensity = model_accuracy if model_accuracy >= 0.7 else 0.3
    return estimated_intensity



# 감정 강도에 따른 글자 크기 스케일링 함수
def scale_font_size(intensity):
    
    # 감정 강도 값의 범위를 설정합니다 (0부터 1까지)
    min_intensity = 0.3
    max_intensity = 1

    # 글자 크기의 범위를 설정합니다 (10부터 20까지)
    min_font_size = 10
    max_font_size = 40
    
    scaled_font_size = round(min_font_size + (max_font_size - min_font_size) * ((intensity - min_intensity) / (max_intensity - min_intensity)))
    return scaled_font_size


# 예측 결과와 모델 정확도를 기반으로 감정의 강도를 추정하고, 텍스트 파일에 매핑하는 함수
def map_emotion_intensity(dataDF, output_filename):   
    with open(output_filename, 'w') as file:    
        for index, row in dataDF.iterrows():
            emotion = row['emotion']  # 예측 결과가 저장된 'emotion' 열을 사용
           # accuracy = row['Model Accuracy']
            predicts = row['predicts']
            emotion_rgb = map_emotion_to_rgb(emotion)
            font_size = scale_font_size(predicts)
           # estimated_intensity = estimate_emotion_intensity(emotion, accuracy)
            line = f"Emotion: {emotion}, Estimated Intensity: {predicts:.2f}, RGB: {emotion_rgb}, Size: {font_size}\n"
            file.write(line)
            

# 학습
def training():

    """Raw Audio Data Labelling"""

    # Define parameters to use for labelling
    labellingFilename = "Labelled_RAVDESS_male_AUDIO"
    feautreOutputFilename = "mfcc_data"
    dataOriginName = "RAVDESS_male"

    # Check for presence or absence of the specified file (create or load file)
    if io_operations.checkIfFileExists(labellingFilename + ".csv", dataOriginName):
        dataDF = io_operations.loadDataset(labellingFilename, dataOriginName)
    else:
        # Load, Label and if needed transcribe an audio dataset
        dataDF = datasource_analysis.identifyData(dataOriginName, "AUDIO", ".csv")

        # Persist the found files and associated values to disk
        io_operations.saveDataset(dataDF, labellingFilename, dataOriginName)

    """Audio Feature Extraction"""

    # Define the list of features, and the required arguments (Originates from Librosa)
    featureSet = ["mfcc"]
    argDict = {'mfcc': {'n_mfcc': 12, 'sr': 48000}}

    # Check for presence or absence of the specified file (create or load file)
    if io_operations.checkIfFileExists(feautreOutputFilename + ".pickle", dataOriginName):
        dataDF = io_operations.loadPickle(feautreOutputFilename, dataOriginName)
    else:
        # Run the feature extraction loop function
        dataDF = feature_extraction_audio.extractFeatures(dataDF, featureSet, argDict, True, 48000, 4)

        # Persist the features to disk, in a loadable pickle form, and viewable csv
        io_operations.savePickle(dataDF, feautreOutputFilename, dataOriginName)
        io_operations.saveDataset(dataDF, feautreOutputFilename, dataOriginName)

    """Audio Model Creation"""

    # Extract the audio features from the dataframe and convert to the required shape
    featureDataFrame = dataDF['mfcc'].values.tolist()
    featureDataFrame = np.asarray(featureDataFrame)

    # Run our model code
    best_model = model_creation_audio.run_model_audio(featureDataFrame, dataDF, "emotion", 5, dataOriginName, 128, 100)  # 모델 생성 코드

    # Calculate model accuracy using the best model
    xAll = np.expand_dims(featureDataFrame, axis=2)
    all_preds = best_model.predict(xAll) # 모델에서는 all predict로 7개의 확률값이 나오고 다 합치면 1이된다.
    # print(all_preds)
    decoded_preds = np.argmax(all_preds, axis=1)  # 7개의 확률값 중에서 가장 큰 값이 있는 위치값(인덱스값)
    preds = np.max(all_preds, axis=1) 
    
    # Calculate model accuracy (using accuracy_score or any other appropriate metric)
    original_labels = dataDF['emotion'].map({'neutral': 0, 'calm': 1, 'happy': 2, 'sad': 3, 'angry': 4, 'fearful': 5, 'disgust': 6, 'surprised':7}).values
    model_accuracy = np.mean(decoded_preds == original_labels)

    # Add 'Model Accuracy' column to the DataFrame
    dataDF['Model Accuracy'] = model_accuracy
    dataDF['predicts'] = preds

    # 감정에 대한 색상 이미지를 보여줍니다
    show_emotion_images(dataDF)

    # 감정의 강도를 추정하고 매핑합니다
    map_emotion_intensity(dataDF, 'EMO_DB_male_mapped_emotion_intensity.txt')

    return best_model, dataDF  # 수정된 데이터프레임 반환

# experiment_1() 함수를 실행하고 그 결과를 받아옵니다
best_model, dataDF = training()
# Out:
# Loading File (Labelled_RAVDESS_male_AUDIO)...
# Loading File (mfcc_data)...
# Epoch 1/100
# 5/5 [==============================] - 8s 423ms/step - loss: 5.5557 - accuracy: 0.1111 - val_loss: 3.9939 - val_accuracy: 0.0833
# Epoch 2/100
# 5/5 [==============================] - 1s 150ms/step - loss: 3.0897 - accuracy: 0.1424 - val_loss: 2.2049 - val_accuracy: 0.1806
# Epoch 3/100
# 5/5 [==============================] - 1s 157ms/step - loss: 2.4180 - accuracy: 0.1441 - val_loss: 2.2405 - val_accuracy: 0.0833
# Epoch 4/100
# 5/5 [==============================] - 1s 153ms/step - loss: 2.2372 - accuracy: 0.1597 - val_loss: 2.0582 - val_accuracy: 0.1319
# Epoch 5/100
# 5/5 [==============================] - 1s 162ms/step - loss: 2.1641 - accuracy: 0.1441 - val_loss: 2.0504 - val_accuracy: 0.1944
# Epoch 6/100
# 5/5 [==============================] - 1s 155ms/step - loss: 2.0859 - accuracy: 0.1476 - val_loss: 2.0533 - val_accuracy: 0.2014
# Epoch 7/100
# 5/5 [==============================] - 1s 162ms/step - loss: 2.1048 - accuracy: 0.1372 - val_loss: 2.0540 - val_accuracy: 0.1528
# Epoch 8/100
# 5/5 [==============================] - 1s 155ms/step - loss: 2.0865 - accuracy: 0.1510 - val_loss: 2.0512 - val_accuracy: 0.1528
# Epoch 9/100
# 5/5 [==============================] - 1s 161ms/step - loss: 2.0796 - accuracy: 0.1562 - val_loss: 2.0400 - val_accuracy: 0.1667
# Epoch 10/100
# 5/5 [==============================] - 1s 158ms/step - loss: 2.0718 - accuracy: 0.1510 - val_loss: 2.0268 - val_accuracy: 0.2083
# Epoch 11/100
# 5/5 [==============================] - 1s 170ms/step - loss: 2.0216 - accuracy: 0.1910 - val_loss: 2.0084 - val_accuracy: 0.1944
# Epoch 12/100
# 5/5 [==============================] - 1s 152ms/step - loss: 2.0061 - accuracy: 0.2205 - val_loss: 1.9847 - val_accuracy: 0.2014
# Epoch 13/100
# 5/5 [==============================] - 1s 146ms/step - loss: 2.0044 - accuracy: 0.1962 - val_loss: 1.9433 - val_accuracy: 0.2292
# Epoch 14/100
# 5/5 [==============================] - 1s 170ms/step - loss: 1.9745 - accuracy: 0.2014 - val_loss: 1.9120 - val_accuracy: 0.2431
# Epoch 15/100
# 5/5 [==============================] - 1s 156ms/step - loss: 1.9472 - accuracy: 0.2309 - val_loss: 1.8657 - val_accuracy: 0.3056
# Epoch 16/100
# 5/5 [==============================] - 1s 159ms/step - loss: 1.9275 - accuracy: 0.2396 - val_loss: 1.8488 - val_accuracy: 0.2500
# Epoch 17/100
# 5/5 [==============================] - 1s 173ms/step - loss: 1.9255 - accuracy: 0.2587 - val_loss: 1.8471 - val_accuracy: 0.2639
100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.5459 - accuracy: 0.7865 - val_loss: 1.2469 - val_accuracy: 0.6042
# Epoch 88/100
# 5/5 [==============================] - 1s 160ms/step - loss: 0.5071 - accuracy: 0.8229 - val_loss: 1.2858 - val_accuracy: 0.6181
# Epoch 89/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.5292 - accuracy: 0.8212 - val_loss: 1.3274 - val_accuracy: 0.6250
# Epoch 90/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.4623 - accuracy: 0.8385 - val_loss: 1.2478 - val_accuracy: 0.6181
# Epoch 91/100
# 5/5 [==============================] - 1s 143ms/step - loss: 0.4970 - accuracy: 0.8125 - val_loss: 1.2728 - val_accuracy: 0.6111
# Epoch 92/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.4648 - accuracy: 0.8472 - val_loss: 1.2981 - val_accuracy: 0.6389
# Epoch 93/100
# 5/5 [==============================] - 1s 157ms/step - loss: 0.4769 - accuracy: 0.8247 - val_loss: 1.2380 - val_accuracy: 0.6528
# Epoch 94/100
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4341 - accuracy: 0.8524 - val_loss: 1.3178 - val_accuracy: 0.6250
# Epoch 95/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.4219 - accuracy: 0.8594 - val_loss: 1.2677 - val_accuracy: 0.6528
# Epoch 96/100
# 5/5 [==============================] - 1s 144ms/step - loss: 0.4454 - accuracy: 0.8472 - val_loss: 1.3654 - val_accuracy: 0.6667
# Epoch 97/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.3854 - accuracy: 0.8490 - val_loss: 1.4090 - val_accuracy: 0.6181
# Epoch 98/100
# 5/5 [==============================] - 1s 146ms/step - loss: 0.3769 - accuracy: 0.8698 - val_loss: 1.2885 - val_accuracy: 0.6250
# Epoch 99/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.4122 - accuracy: 0.8438 - val_loss: 1.4407 - val_accuracy: 0.6181
# Epoch 100/100
# 5/5 [==============================] - 1s 161ms/step - loss: 0.4121 - accuracy: 0.8403 - val_loss: 1.3142 - val_accuracy: 0.6667
# 5/5 [==============================] - 1s 16ms/step
#
# Predictions:
#      predictedValues
# 0              calm
# 1               sad
# 2              calm
# 3              calm
# 4             happy
# ..              ...
# 139         disgust
# 140         fearful
# 141         disgust
# 142       surprised
# 143       surprised
#
# [144 rows x 1 columns]
# Model Accuracy: 0.6666666666666666
# Conf Matrix:
#  [[15  0  2  0  0  0  1  0]
#  [ 0 18  0  0  0  0  0  1]
#  [ 0  0 12  0  0  0  0  0]
#  [ 6  1  2 11  2  0  6  2]
#  [ 1  0  0  2  9  0  4  1]
#  [ 0  2  0  0  0  5  3  0]
#  [ 0  3  0  2  0  1 10  1]
#  [ 0  0  1  2  2  0  0 16]]
#               precision    recall  f1-score   support
#
#        angry       0.68      0.83      0.75        18
#         calm       0.75      0.95      0.84        19
#      disgust       0.71      1.00      0.83        12
#      fearful       0.65      0.37      0.47        30
#        happy       0.69      0.53      0.60        17
#      neutral       0.83      0.50      0.62        10
#          sad       0.42      0.59      0.49        17
#    surprised       0.76      0.76      0.76        21
#
#     accuracy                           0.67       144
#    macro avg       0.69      0.69      0.67       144
# weighted avg       0.68      0.67      0.65       144
#
# IO LOG - Storing Model Results in: results\RAVDESS_male_10-17-2023-17-12-03
# results\RAVDESS_male_10-17-2023-17-12-03\RAVDESS_male-iter-0-cnnHistory.png
# IO Log - Saved trained model at results\RAVDESS_male_10-17-2023-17-12-03\RAVDESS_male-iter-0\RAVDESS_male-iter-0.h5
# Epoch 1/100
# 5/5 [==============================] - 4s 213ms/step - loss: 5.1741 - accuracy: 0.1250 - val_loss: 3.0612 - val_accuracy: 0.1458
# Epoch 2/100
# 5/5 [==============================] - 1s 142ms/step - loss: 2.6444 - accuracy: 0.1337 - val_loss: 2.1901 - val_accuracy: 0.1111
# Epoch 3/100
100
# 5/5 [==============================] - 1s 147ms/step - loss: 0.3715 - accuracy: 0.8715 - val_loss: 0.9987 - val_accuracy: 0.6875
# Epoch 97/100
# 5/5 [==============================] - 1s 131ms/step - loss: 0.3866 - accuracy: 0.8490 - val_loss: 0.9387 - val_accuracy: 0.6736
# Epoch 98/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.3853 - accuracy: 0.8663 - val_loss: 0.9966 - val_accuracy: 0.6806
# Epoch 99/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.3813 - accuracy: 0.8785 - val_loss: 1.0410 - val_accuracy: 0.6597
# Epoch 100/100
# 5/5 [==============================] - 1s 135ms/step - loss: 0.3534 - accuracy: 0.8663 - val_loss: 0.9689 - val_accuracy: 0.6806
# 5/5 [==============================] - 0s 14ms/step
#
# Predictions:
#      predictedValues
# 0           neutral
# 1           neutral
# 2              calm
# 3             happy
# 4               sad
# ..              ...
# 139         fearful
# 140         fearful
# 141         disgust
# 142       surprised
# 143       surprised
#
# [144 rows x 1 columns]
# Model Accuracy: 0.6805555555555556
# Conf Matrix:
#  [[13  0  1  0  2  0  0  0]
#  [ 1 16  0  0  1  1  0  2]
#  [ 2  0 12  5  2  0  0  0]
#  [ 1  2  0 15  0  0  2  1]
#  [ 2  0  1  0 13  0  0  0]
#  [ 0  0  0  0  2  6  0  0]
#  [ 0  2  1  1  2  3 11  1]
#  [ 0  0  0  4  4  0  0 12]]
#               precision    recall  f1-score   support
#
#        angry       0.68      0.81      0.74        16
#         calm       0.80      0.76      0.78        21
#      disgust       0.80      0.57      0.67        21
#      fearful       0.60      0.71      0.65        21
#        happy       0.50      0.81      0.62        16
#      neutral       0.60      0.75      0.67         8
#          sad       0.85      0.52      0.65        21
#    surprised       0.75      0.60      0.67        20
#
#     accuracy                           0.68       144
#    macro avg       0.70      0.69      0.68       144
# weighted avg       0.71      0.68      0.68       144
#
# results\RAVDESS_male_10-17-2023-17-12-03\RAVDESS_male-iter-1-cnnHistory.png
# IO Log - Saved trained model at results\RAVDESS_male_10-17-2023-17-12-03\RAVDESS_male-iter-1\RAVDESS_male-iter-1.h5
# Epoch 1/100
# 5/5 [==============================] - 3s 241ms/step - loss: 5.5455 - accuracy: 0.1250 - val_loss: 2.8382 - val_accuracy: 0.1111
# Epoch 2/100
# 5/5 [==============================] - 1s 130ms/step - loss: 2.6615 - accuracy: 0.1528 - val_loss: 2.1907 - val_accuracy: 0.1597
# Epoch 3/100
# 5/5 [==============================] - 1s 142ms/step - loss: 2.4296 - accuracy: 0.1250 - val_loss: 2.2297 - val_accuracy: 0.1042
# Epoch 4/100
# 5/5 [==============================] - 1s 128ms/step - loss: 2.2060 - accuracy: 0.1458 - val_loss: 2.1011 - val_accuracy: 0.0972
# Epoch 5/100
# 5/5 [==============================] - 1s 137ms/step - loss: 2.1363 - accuracy: 0.1441 - val_loss: 2.0544 - val_accuracy: 0.1042
# Epoch 6/100
# 5/5 [==============================] - 1s 141ms/step - loss: 2.1228 - accuracy: 0.1562 - val_loss: 2.0377 - val_accuracy: 0.1458
# Epoch 7/100
# 5/5 [==============================] - 1s 138ms/step - loss: 2.0530 - accuracy: 0.1684 - val_loss: 2.0301 - val_accuracy: 0.2083
# Epoch 8/100
# 5/5 [==============================] - 1s 135ms/step - loss: 2.0474 - accuracy: 0.1910 - val_loss: 2.0445 - val_accuracy: 0.1528
# Epoch 9/100
# 5/5 [==============================] - 1s 138ms/step - loss: 2.0351 - accuracy: 0.1788 - val_loss: 2.0078 - val_accuracy: 0.2153
# Epoch 10/100
# 5/5 [==============================] - 1s 141ms/step - loss: 2.0035 - accuracy: 0.1997 - val_loss: 1.9853 - val_accuracy: 0.1806
# Epoch 11/100
# 5/5 [==============================] - 1s 135ms/step - loss: 1
100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.5772 - accuracy: 0.7865 - val_loss: 0.9547 - val_accuracy: 0.6944
# Epoch 84/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.5275 - accuracy: 0.8264 - val_loss: 0.9734 - val_accuracy: 0.6458
# Epoch 85/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.5515 - accuracy: 0.8038 - val_loss: 0.9507 - val_accuracy: 0.6597
# Epoch 86/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.4617 - accuracy: 0.8507 - val_loss: 1.0379 - val_accuracy: 0.6389
# Epoch 87/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.5154 - accuracy: 0.8194 - val_loss: 0.9603 - val_accuracy: 0.6667
# Epoch 88/100
# 5/5 [==============================] - 0s 98ms/step - loss: 0.4881 - accuracy: 0.8316 - val_loss: 0.9379 - val_accuracy: 0.6944
# Epoch 89/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.4721 - accuracy: 0.8351 - val_loss: 0.9680 - val_accuracy: 0.6736
# Epoch 90/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.4503 - accuracy: 0.8316 - val_loss: 0.9809 - val_accuracy: 0.6736
# Epoch 91/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.4443 - accuracy: 0.8385 - val_loss: 0.9488 - val_accuracy: 0.7014
# Epoch 92/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.3976 - accuracy: 0.8611 - val_loss: 0.9917 - val_accuracy: 0.6597
# Epoch 93/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.4266 - accuracy: 0.8472 - val_loss: 0.9684 - val_accuracy: 0.6875
# Epoch 94/100
# 5/5 [==============================] - 0s 79ms/step - loss: 0.4380 - accuracy: 0.8316 - val_loss: 0.9486 - val_accuracy: 0.6667
# Epoch 95/100
# 5/5 [==============================] - 0s 91ms/step - loss: 0.3982 - accuracy: 0.8750 - val_loss: 0.9940 - val_accuracy: 0.6597
# Epoch 96/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.4279 - accuracy: 0.8490 - val_loss: 0.9343 - val_accuracy: 0.7014
# Epoch 97/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.4046 - accuracy: 0.8767 - val_loss: 1.0511 - val_accuracy: 0.6458
# Epoch 98/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.3774 - accuracy: 0.8854 - val_loss: 0.9352 - val_accuracy: 0.6806
# Epoch 99/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.3964 - accuracy: 0.8611 - val_loss: 0.9746 - val_accuracy: 0.6597
# Epoch 100/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.3465 - accuracy: 0.8785 - val_loss: 1.0521 - val_accuracy: 0.6597
# 5/5 [==============================] - 0s 9ms/step
#
# Predictions:
#      predictedValues
# 0              calm
# 1              calm
# 2         surprised
# 3         surprised
# 4           fearful
# ..              ...
# 139           angry
# 140         neutral
# 141       surprised
# 142         disgust
# 143           happy
#
# [144 rows x 1 columns]
# Model Accuracy: 0.6597222222222222
# Conf Matrix:
#  [[22  0  3  1  0  0  0  0]
#  [ 0 15  0  0  0  0  0  0]
#  [ 1  1 10  0  2  0  0  3]
#  [ 0  0  1 12  1  1  0  1]
#  [ 0  0  2  1  7  0  1  3]
#  [ 0  5  0  0  0  8  0  1]
#  [ 2  3  2  3  2  3  7  1]
#  [ 1  0  0  1  3  0  0 14]]
#               precision    recall  f1-score   support
#
#        angry       0.85      0.85      0.85        26
#         calm       0.62      1.00      0.77        15
#      disgust       0.56      0.59      0.57        17
#      fearful       0.67      0.75      0.71        16
#        happy       0.47      0.50      0.48        14
#      neutral       0.67      0.57      0.62        14
#          sad       0.88      0.30      0.45        23
#    surprised       0.61      0.74      0.67        19
#
#     accuracy                           0.66       144
#    macro avg       0.66      0.66      0.64       144
# weighted avg       0.69      0.66      0.65       144
#
# results\RAVDESS_male_10-17-2023-17-12-03\RAVDESS_male-iter
100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6060 - accuracy: 0.8038 - val_loss: 1.1191 - val_accuracy: 0.6111
# Epoch 88/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6157 - accuracy: 0.7812 - val_loss: 1.2041 - val_accuracy: 0.5833
# Epoch 89/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.6084 - accuracy: 0.7743 - val_loss: 1.1472 - val_accuracy: 0.5833
# Epoch 90/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.6184 - accuracy: 0.7691 - val_loss: 1.0775 - val_accuracy: 0.6181
# Epoch 91/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.5915 - accuracy: 0.7674 - val_loss: 1.1457 - val_accuracy: 0.5972
# Epoch 92/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.5588 - accuracy: 0.7812 - val_loss: 1.1795 - val_accuracy: 0.5833
# Epoch 93/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.5664 - accuracy: 0.7899 - val_loss: 1.0966 - val_accuracy: 0.6181
# Epoch 94/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.5261 - accuracy: 0.8056 - val_loss: 1.1762 - val_accuracy: 0.6042
# Epoch 95/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.5487 - accuracy: 0.8038 - val_loss: 1.2323 - val_accuracy: 0.5694
# Epoch 96/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.5399 - accuracy: 0.7917 - val_loss: 1.1469 - val_accuracy: 0.6111
# Epoch 97/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.5005 - accuracy: 0.8316 - val_loss: 1.1307 - val_accuracy: 0.6111
# Epoch 98/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.5241 - accuracy: 0.8038 - val_loss: 1.1207 - val_accuracy: 0.6389
# Epoch 99/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.5267 - accuracy: 0.8073 - val_loss: 1.1790 - val_accuracy: 0.6042
# Epoch 100/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.4617 - accuracy: 0.8403 - val_loss: 1.0911 - val_accuracy: 0.6042
# 5/5 [==============================] - 0s 10ms/step
#
# Predictions:
#      predictedValues
# 0              calm
# 1              calm
# 2           neutral
# 3             angry
# 4             happy
# ..              ...
# 139           angry
# 140           angry
# 141             sad
# 142         disgust
# 143       surprised
#
# [144 rows x 1 columns]
# Model Accuracy: 0.6041666666666666
# Conf Matrix:
#  [[11  1  1  2  1  0  0  2]
#  [ 0 12  1  2  0  3  1  0]
#  [ 0  0 15  1  2  1  4  3]
#  [ 0  0  3  6  0  0  3  0]
#  [ 1  0  1  2 15  1  4  2]
#  [ 0  1  0  0  0  5  0  0]
#  [ 0  1  0  2  2  1 15  1]
#  [ 2  0  3  0  1  0  1  8]]
#               precision    recall  f1-score   support
#
#        angry       0.79      0.61      0.69        18
#         calm       0.80      0.63      0.71        19
#      disgust       0.62      0.58      0.60        26
#      fearful       0.40      0.50      0.44        12
#        happy       0.71      0.58      0.64        26
#      neutral       0.45      0.83      0.59         6
#          sad       0.54      0.68      0.60        22
#    surprised       0.50      0.53      0.52        15
#
#     accuracy                           0.60       144
#    macro avg       0.60      0.62      0.60       144
# weighted avg       0.63      0.60      0.61       144
#
# results\RAVDESS_male_10-17-2023-17-12-03\RAVDESS_male-iter-4-cnnHistory.png
# IO Log - Saved trained model at results\RAVDESS_male_10-17-2023-17-12-03\RAVDESS_male-iter-4\RAVDESS_male-iter-4.h5
# Run Summary:
# Min: 0.5833333333333334
# Max: 0.6805555555555556
# Mean: 0.638888888888889
# 23/23 [==============================] - 0s 11ms/step
