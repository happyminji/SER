# %% [markdown]
# ## - STT로 생성된 텍스트 파일에 색상을 매핑

# %%
import csv

# 감정-색상 매핑 테이블
emotion_to_rgb = {
    "neutral": (30, 40, 30),
    "sadness": (40, 0, 80),
    "happy": (210, 255, 10),
    "hot anger": (255, 0, 0),
    "disgust": (0, 112, 192),
    "boredom": (255, 255, 255),
    "anxiety": (127, 127, 127),
    # 추가적인 감정과 RGB 값 매핑을 계속 추가할 수 있음
}
             
# CSV 파일 읽기
file_path = r'E:\9.21 ser\Emo-DB SER_0821\SER_Platform_AICS\datasets\LDC_male\\labelled_LDC_male_AUDIO.csv'
with open(file_path, 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        emotion = row['emotion']
        statements = row['statements']
        situation = row['situation']
        gender = row['gender']

        
        # 감정에 대응하는 색상 가져오기
        color = emotion_to_rgb.get(emotion, 'unknown')
        
        # 색상 정보를 포함한 텍스트 생성
        colored_text = f"situation: {situation}, Emotion: {emotion}, statements: {statements}, Gender: {gender}, Color: {color}"
        
        # 생성된 텍스트를 파일에 추가
        with open('LDC_male_output_text.txt', 'a') as korean_output_file:
            korean_output_file.write(colored_text + '\n')

print("색상 매핑이 완료되었습니다.")
# Out:
# 색상 매핑이 완료되었습니다.

# %%
# 필요한 라이브러리 가져오기
import numpy as np
import itertools
import matplotlib.pyplot as plt  # matplotlib 추가

# Project Level Imports
import datasource_analysis
import feature_extraction_audio
import io_operations
import model_creation_audio
import model_evaluation_audio
import config

# 감정 레이블을 RGB 값으로 매핑하는 함수 정의
def map_emotion_to_rgb(emotion):
    emotion_to_rgb = {
        "neutral": (30, 40, 30),
        "sadness": (40, 0, 80),
        "happy": (210, 255, 10),
        "hot anger": (255, 0, 0),
        "disgust": (0, 112, 192),
        "boredom": (255, 255, 255),
        "anxiety": (127, 127, 127),
        # 추가적인 감정과 RGB 값 매핑을 계속 추가할 수 있음
    }
    return emotion_to_rgb.get(emotion, (0, 0, 0))  # 기본값은 검은색

def show_emotion_images(dataDF):
    # 감정 레이블에 해당하는 RGB 값을 활용하여 색상 이미지를 생성하고 표시
    emotions = dataDF['emotion'].unique()
    fig, axs = plt.subplots(3, 4, figsize=(12, 8))

    for idx, emotion in enumerate(emotions):
        ax = axs[idx // 4, idx % 4]
        rgb = map_emotion_to_rgb(emotion)
        ax.imshow([[rgb]], extent=(0, 1, 0, 1))
        ax.set_title(emotion)
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# 감정의 강도를 추정하는 함수
def estimate_emotion_intensity(predicted_emotion, model_accuracy):
    # 감정 강도 추정 방식을 정의합니다
    estimated_intensity = model_accuracy if model_accuracy >= 0.7 else 0.3
    return estimated_intensity



# 감정 강도에 따른 글자 크기 스케일링 함수
def scale_font_size(intensity):
    
    # 감정 강도 값의 범위를 설정합니다 (0부터 1까지)
    min_intensity = 0.3
    max_intensity = 1

    # 글자 크기의 범위를 설정합니다 (10부터 20까지)
    min_font_size = 10
    max_font_size = 40
    
    scaled_font_size = round(min_font_size + (max_font_size - min_font_size) * ((intensity - min_intensity) / (max_intensity - min_intensity)))
    return scaled_font_size


# 예측 결과와 모델 정확도를 기반으로 감정의 강도를 추정하고, 텍스트 파일에 매핑하는 함수
def map_emotion_intensity(dataDF, output_filename):   
    with open(output_filename, 'w') as file:    
        for index, row in dataDF.iterrows():
            emotion = row['emotion']  # 예측 결과가 저장된 'emotion' 열을 사용
           # accuracy = row['Model Accuracy']
            predicts = row['predicts']
            emotion_rgb = map_emotion_to_rgb(emotion)
            font_size = scale_font_size(predicts)
           # estimated_intensity = estimate_emotion_intensity(emotion, accuracy)
            line = f"Emotion: {emotion}, Estimated Intensity: {predicts:.2f}, RGB: {emotion_rgb}, Size: {font_size}\n"
            file.write(line)
            

# 학습
def training():

    """Raw Audio Data Labelling"""

    # Define parameters to use for labelling
    labellingFilename = "labelled_LDC_male_AUDIO"
    feautreOutputFilename = "mfcc_data"
    dataOriginName = "LDC_male"

    # Check for presence or absence of the specified file (create or load file)
    if io_operations.checkIfFileExists(labellingFilename + ".csv", dataOriginName):
        dataDF = io_operations.loadDataset(labellingFilename, dataOriginName)
    else:
        # Load, Label and if needed transcribe an audio dataset
        dataDF = datasource_analysis.identifyData(dataOriginName, "AUDIO", ".csv")

        # Persist the found files and associated values to disk
        io_operations.saveDataset(dataDF, labellingFilename, dataOriginName)

    """Audio Feature Extraction"""

    # Define the list of features, and the required arguments (Originates from Librosa)
    featureSet = ["mfcc"]
    argDict = {'mfcc': {'n_mfcc': 12, 'sr': 48000}}

    # Check for presence or absence of the specified file (create or load file)
    if io_operations.checkIfFileExists(feautreOutputFilename + ".pickle", dataOriginName):
        dataDF = io_operations.loadPickle(feautreOutputFilename, dataOriginName)
    else:
        # Run the feature extraction loop function
        dataDF = feature_extraction_audio.extractFeatures(dataDF, featureSet, argDict, True, 48000, 4)

        # Persist the features to disk, in a loadable pickle form, and viewable csv
        io_operations.savePickle(dataDF, feautreOutputFilename, dataOriginName)
        io_operations.saveDataset(dataDF, feautreOutputFilename, dataOriginName)

    """Audio Model Creation"""

    # Extract the audio features from the dataframe and convert to the required shape
    featureDataFrame = dataDF['mfcc'].values.tolist()
    featureDataFrame = np.asarray(featureDataFrame)

    # Run our model code
    best_model = model_creation_audio.run_model_audio(featureDataFrame, dataDF, "emotion", 5, dataOriginName, 128, 100)  # 모델 생성 코드

    # Calculate model accuracy using the best model
    xAll = np.expand_dims(featureDataFrame, axis=2)
    all_preds = best_model.predict(xAll) # 모델에서는 all predict로 7개의 확률값이 나오고 다 합치면 1이된다.
    # print(all_preds)
    decoded_preds = np.argmax(all_preds, axis=1)  # 7개의 확률값 중에서 가장 큰 값이 있는 위치값(인덱스값)
    preds = np.max(all_preds, axis=1) 
    
    # Calculate model accuracy (using accuracy_score or any other appropriate metric)
    original_labels = dataDF['emotion'].map({'neutral': 0, 'sadness': 1, 'happy': 2, 'hot anger': 3, 'disgust': 4, 'boredom': 5, 'anxiety': 6}).values
    model_accuracy = np.mean(decoded_preds == original_labels)

    # Add 'Model Accuracy' column to the DataFrame
    dataDF['Model Accuracy'] = model_accuracy
    dataDF['predicts'] = preds

    # 감정에 대한 색상 이미지를 보여줍니다
    show_emotion_images(dataDF)

    # 감정의 강도를 추정하고 매핑합니다
    map_emotion_intensity(dataDF, 'LDC_male_mapped_emotion_intensity.txt')

    return best_model, dataDF  # 수정된 데이터프레임 반환

# experiment_1() 함수를 실행하고 그 결과를 받아옵니다
best_model, dataDF = training()
# Out:
# Loading File (labelled_LDC_male_AUDIO)...
# Starting audio feature extraction
# Features: ['mfcc']
# Warning - This may take some time...
# Extracting Features for: datasources\LDC_male\wav\1AX1s0020.wav at 10/18/2023, 15:06:14
# Extracting Features for: datasources\LDC_male\wav\1AX1s0021.wav at 10/18/2023, 15:06:15
# Extracting Features for: datasources\LDC_male\wav\1AX1s0040.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1AX1s0060.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1AX1s0061.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1AX1s0080.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1AX1s0081.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1AX1s0090.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1AX1s0091.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1AX1s3450.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1BD1s0100.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1BD1s0101.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1BD1s0110.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1BD1s0111.wav at 10/18/2023, 15:06:16
# Extracting Features for: datasources\LDC_male\wav\1BD1s0120.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s0150.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s0151.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s0160.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s0180.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s0181.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s0190.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s0200.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s0201.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1BD1s3360.wav at 10/18/2023, 15:06:17
# Extracting Features for: datasources\LDC_male\wav\1DG1s0420.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0421.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0422.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0423.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0424.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0425.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0430.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0431.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0432.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0433.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0440.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0441.wav at 10/18/2023, 15:06:18
# Extracting Features for: datasources\LDC_male\wav\1DG1s0442.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0460.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0461.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0462.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0470.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0471.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0472.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0480.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0481.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0482.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0490.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0491.wav at 10/18/2023, 15:06:19
# Extracting Features for: datasources\LDC_male\wav\1DG1s0500.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1DG1s0510.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1DG1s0511.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1DG1s0520.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s0950.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s0951.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s0952.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s0960.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s0970.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s0980.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s1000.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s1010.wav at 10/18/2023, 15:06:20
# Extracting Features for: datasources\LDC_male\wav\1HA1s1030.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HA1s1031.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HA1s1040.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HA1s1041.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HA1s3300.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HA1s3520.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HP1s0740.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HP1s0741.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HP1s1050.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HP1s1051.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HP1s1070.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HP1s1071.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HP1s1080.wav at 10/18/2023, 15:06:21
# Extracting Features for: datasources\LDC_male\wav\1HP1s1081.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1082.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1090.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1091.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1100.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1101.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1110.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1111.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1120.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1121.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1122.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1123.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1130.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1140.wav at 10/18/2023, 15:06:22
# Extracting Features for: datasources\LDC_male\wav\1HP1s1141.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1HP1s1142.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s0170.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s0171.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s0370.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s0390.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s0780.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s0781.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s0810.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s0820.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s1050.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s1070.wav at 10/18/2023, 15:06:23
# Extracting Features for: datasources\LDC_male\wav\1NT1s1140.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1141.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1180.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1280.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1281.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1320.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1330.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1360.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1370.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1410.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1411.wav at 10/18/2023, 15:06:24
# Extracting Features for: datasources\LDC_male\wav\1NT1s1440.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1450.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1520.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1550.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1580.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1640.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1670.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1720.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1740.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1760.wav at 10/18/2023, 15:06:25
# Extracting Features for: datasources\LDC_male\wav\1NT1s1780.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1800.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1830.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1831.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1832.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1840.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1841.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1842.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1843.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1844.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1845.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1850.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1860.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1870.wav at 10/18/2023, 15:06:26
# Extracting Features for: datasources\LDC_male\wav\1NT1s1871.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT1s1880.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT1s1881.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT1s1882.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT1s3360.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT1s3420.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT1s3510.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT2s0100.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT2s0120.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT2s0200.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT2s0201.wav at 10/18/2023, 15:06:27
# Extracting Features for: datasources\LDC_male\wav\1NT2s0290.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s0291.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s0340.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s0360.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s0800.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s0801.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s0860.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s0861.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s0862.wav at 10/18/2023, 15:06:28
# Extracting Features for: datasources\LDC_male\wav\1NT2s1120.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1130.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1150.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1220.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1260.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1261.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1290.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1300.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1390.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1420.wav at 10/18/2023, 15:06:29
# Extracting Features for: datasources\LDC_male\wav\1NT2s1480.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1481.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1500.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1530.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1560.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1590.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1591.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1600.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1601.wav at 10/18/2023, 15:06:30
# Extracting Features for: datasources\LDC_male\wav\1NT2s1630.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT2s1700.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT2s1701.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT2s1750.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT2s1820.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT2s1860.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT2s3240.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT2s3460.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT3s0160.wav at 10/18/2023, 15:06:31
# Extracting Features for: datasources\LDC_male\wav\1NT3s0180.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s0181.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s0320.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1080.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1100.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1190.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1240.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1241.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1270.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1310.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1340.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1350.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1380.wav at 10/18/2023, 15:06:32
# Extracting Features for: datasources\LDC_male\wav\1NT3s1400.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1430.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1540.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1570.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1610.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1611.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1660.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1661.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1710.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1730.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1770.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1790.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1810.wav at 10/18/2023, 15:06:33
# Extracting Features for: datasources\LDC_male\wav\1NT3s1840.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1NT3s3280.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1NT3s3340.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1NT3s3400.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1NT3s3500.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1NT3s3550.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1SN1s2190.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1SN1s2191.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1SN1s2200.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1SN1s2210.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1SN1s2230.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1SN1s2231.wav at 10/18/2023, 15:06:34
# Extracting Features for: datasources\LDC_male\wav\1SN1s2240.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\1SN1s2250.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\1SN1s2251.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\1SN1s2260.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\1SN1s2280.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\1SN1s3430.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\1SN1s3431.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\2AX1s2290.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\2AX1s2291.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\2AX1s2300.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\2AX1s2301.wav at 10/18/2023, 15:06:35
# Extracting Features for: datasources\LDC_male\wav\2AX1s2302.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2310.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2311.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2330.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2331.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2340.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2341.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2350.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2360.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2361.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2370.wav at 10/18/2023, 15:06:36
# Extracting Features for: datasources\LDC_male\wav\2AX1s2371.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2AX1s2630.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2AX1s2980.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2AX1s3350.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2AX1s3351.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2AX1s3352.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2BD1s0550.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2BD1s0551.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2BD1s0552.wav at 10/18/2023, 15:06:37
# Extracting Features for: datasources\LDC_male\wav\2BD1s0720.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s0721.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s0722.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s1270.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s1271.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s1360.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s1361.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s1400.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s1401.wav at 10/18/2023, 15:06:38
# Extracting Features for: datasources\LDC_male\wav\2BD1s1402.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s1403.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s1560.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s1561.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s1780.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s1781.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s1782.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s1783.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s2090.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s2091.wav at 10/18/2023, 15:06:39
# Extracting Features for: datasources\LDC_male\wav\2BD1s2092.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2BD1s2093.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2BD1s3260.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2BD1s3261.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2BD1s3262.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2BD1s3460.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2BD1s3461.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2DG1s2460.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2DG1s2461.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2DG1s2470.wav at 10/18/2023, 15:06:40
# Extracting Features for: datasources\LDC_male\wav\2DG1s2471.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2480.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2481.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2482.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2483.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2490.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2491.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2510.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2511.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2520.wav at 10/18/2023, 15:06:41
# Extracting Features for: datasources\LDC_male\wav\2DG1s2521.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2DG1s2550.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2DG1s2551.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2DG1s3290.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2DG1s3291.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2DG1s3490.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2DG1s3491.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2DG1s3540.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2DG1s3541.wav at 10/18/2023, 15:06:42
# Extracting Features for: datasources\LDC_male\wav\2HA1s1140.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s1141.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s1150.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s1151.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s2620.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s2621.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s2622.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s2720.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s2721.wav at 10/18/2023, 15:06:43
# Extracting Features for: datasources\LDC_male\wav\2HA1s2730.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2731.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2740.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2741.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2742.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2750.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2751.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2760.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2761.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2770.wav at 10/18/2023, 15:06:44
# Extracting Features for: datasources\LDC_male\wav\2HA1s2771.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HA1s2772.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HA1s2780.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HA1s2781.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HA1s3390.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HA1s3391.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HA1s3392.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HP1s0630.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HP1s0631.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HP1s0670.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HP1s0671.wav at 10/18/2023, 15:06:45
# Extracting Features for: datasources\LDC_male\wav\2HP1s1290.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1291.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1310.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1311.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1420.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1421.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1580.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1581.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1582.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1730.wav at 10/18/2023, 15:06:46
# Extracting Features for: datasources\LDC_male\wav\2HP1s1731.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2HP1s2030.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2HP1s2031.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2HP1s2170.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2HP1s2171.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2HP1s3510.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2HP1s3511.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2NT1s0060.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2NT1s0061.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2NT1s0062.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2NT1s0270.wav at 10/18/2023, 15:06:47
# Extracting Features for: datasources\LDC_male\wav\2NT1s0271.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0272.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0470.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0471.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0780.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0781.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0782.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0890.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0891.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0940.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0941.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0942.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0950.wav at 10/18/2023, 15:06:48
# Extracting Features for: datasources\LDC_male\wav\2NT1s0951.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s0980.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s0981.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s0982.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1820.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1821.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1822.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1823.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1830.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1831.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1832.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1840.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1850.wav at 10/18/2023, 15:06:49
# Extracting Features for: datasources\LDC_male\wav\2NT1s1851.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1852.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1860.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1861.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1870.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1871.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1872.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1880.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1881.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1970.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1971.wav at 10/18/2023, 15:06:50
# Extracting Features for: datasources\LDC_male\wav\2NT1s1972.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2120.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2121.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2122.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2190.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2191.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2210.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2211.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2300.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2301.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2360.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2361.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2362.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2363.wav at 10/18/2023, 15:06:51
# Extracting Features for: datasources\LDC_male\wav\2NT1s2380.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2381.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2382.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2400.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2401.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2402.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2450.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2451.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2470.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2471.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2670.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2671.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2672.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2760.wav at 10/18/2023, 15:06:52
# Extracting Features for: datasources\LDC_male\wav\2NT1s2761.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s2770.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s2771.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s2772.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s2890.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s2891.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s2910.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s2911.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s3200.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s3201.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s3202.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s3250.wav at 10/18/2023, 15:06:53
# Extracting Features for: datasources\LDC_male\wav\2NT1s3251.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3252.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3310.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3311.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3380.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3381.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3470.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3471.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3472.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3540.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT1s3541.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT2s0030.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT2s0031.wav at 10/18/2023, 15:06:54
# Extracting Features for: datasources\LDC_male\wav\2NT2s0090.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0091.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0092.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0210.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0211.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0240.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0241.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0242.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0243.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0430.wav at 10/18/2023, 15:06:55
# Extracting Features for: datasources\LDC_male\wav\2NT2s0431.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0432.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0510.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0511.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0512.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0920.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0921.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0922.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0960.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0961.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0962.wav at 10/18/2023, 15:06:56
# Extracting Features for: datasources\LDC_male\wav\2NT2s0963.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s1030.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s1031.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s1032.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s1840.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s1841.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s1842.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s1940.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s1941.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s2250.wav at 10/18/2023, 15:06:57
# Extracting Features for: datasources\LDC_male\wav\2NT2s2251.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2252.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2260.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2261.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2262.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2350.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2351.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2352.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2353.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2420.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2421.wav at 10/18/2023, 15:06:58
# Extracting Features for: datasources\LDC_male\wav\2NT2s2440.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2441.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2510.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2511.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2640.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2641.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2650.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2651.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2652.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2710.wav at 10/18/2023, 15:06:59
# Extracting Features for: datasources\LDC_male\wav\2NT2s2711.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2712.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2713.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2740.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2741.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2742.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2750.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2751.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2752.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2810.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2811.wav at 10/18/2023, 15:07:00
# Extracting Features for: datasources\LDC_male\wav\2NT2s2812.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2820.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2821.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2830.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2831.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2832.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2930.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2931.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2932.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s2933.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s3290.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s3291.wav at 10/18/2023, 15:07:01
# Extracting Features for: datasources\LDC_male\wav\2NT2s3350.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT2s3351.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT2s3352.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT2s3410.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT2s3411.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT2s3500.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT2s3501.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT2s3502.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT3s0070.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT3s0071.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT3s0072.wav at 10/18/2023, 15:07:02
# Extracting Features for: datasources\LDC_male\wav\2NT3s0220.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0221.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0290.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0291.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0292.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0460.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0461.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0490.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0491.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0492.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0493.wav at 10/18/2023, 15:07:03
# Extracting Features for: datasources\LDC_male\wav\2NT3s0770.wav at 10/18/2023, 15:07:04
# Extracting Features for: datasources\LDC_male\wav\2NT3s0771.wav at 10/18/2023, 15:07:04
# Extracting Features for: datasources\LDC_male\wav\2NT3s0772.wav at 10/18/2023, 15:07:04
# Extracting Features for: datasources\LDC_male\wav\2NT3s0773.wav at 10/18/2023, 15:07:04
# Extracting Features for: datasources\LDC_male\wav\2NT3s0780.wav at 10/18/2023, 15:07:04
# Extracting Features for: datasources\LDC_male\wav\2NT3s0781.wav at 10/18/2023, 15:07:04
# ...
#      sadness       0.73      0.73      0.73        11
#
#     accuracy                           0.85       186
#    macro avg       0.71      0.64      0.66       186
# weighted avg       0.85      0.85      0.84       186
#
# results\LDC_male_10-18-2023-15-08-51\LDC_male-iter-3-cnnHistory.png
# IO Log - Saved trained model at results\LDC_male_10-18-2023-15-08-51\LDC_male-iter-3\LDC_male-iter-3.h5
# Epoch 1/100
# 6/6 [==============================] - 2s 128ms/step - loss: 3.4213 - accuracy: 0.3763 - val_loss: 1.4035 - val_accuracy: 0.6505
# Epoch 2/100
# 6/6 [==============================] - 0s 84ms/step - loss: 1.7633 - accuracy: 0.5363 - val_loss: 1.2810 - val_accuracy: 0.6505
# Epoch 3/100
# 6/6 [==============================] - 1s 87ms/step - loss: 1.5130 - accuracy: 0.5820 - val_loss: 1.2744 - val_accuracy: 0.6505
# Epoch 4/100
# 6/6 [==============================] - 0s 84ms/step - loss: 1.4406 - accuracy: 0.5968 - val_loss: 1.2357 - val_accuracy: 0.6505
# Epoch 5/100
# 6/6 [==============================] - 1s 87ms/step - loss: 1.4073 - accuracy: 0.6008 - val_loss: 1.2507 - val_accuracy: 0.6505
# Epoch 6/100
# 6/6 [==============================] - 0s 84ms/step - loss: 1.3749 - accuracy: 0.6035 - val_loss: 1.1893 - val_accuracy: 0.6505
# Epoch 7/100
# 6/6 [==============================] - 1s 87ms/step - loss: 1.3564 - accuracy: 0.5995 - val_loss: 1.2153 - val_accuracy: 0.6505
# Epoch 8/100
# 6/6 [==============================] - 0s 84ms/step - loss: 1.3339 - accuracy: 0.6008 - val_loss: 1.1786 - val_accuracy: 0.6559
# Epoch 9/100
# 6/6 [==============================] - 1s 86ms/step - loss: 1.3023 - accuracy: 0.6022 - val_loss: 1.1090 - val_accuracy: 0.6559
# Epoch 10/100
# 6/6 [==============================] - 0s 84ms/step - loss: 1.2539 - accuracy: 0.6075 - val_loss: 1.1506 - val_accuracy: 0.6613
# Epoch 11/100
# 6/6 [==============================] - 1s 86ms/step - loss: 1.2277 - accuracy: 0.6048 - val_loss: 1.0289 - val_accuracy: 0.6505
# Epoch 12/100
# 6/6 [==============================] - 0s 85ms/step - loss: 1.1925 - accuracy: 0.5995 - val_loss: 0.9972 - val_accuracy: 0.6828
# Epoch 13/100
# 6/6 [==============================] - 1s 86ms/step - loss: 1.1475 - accuracy: 0.6008 - val_loss: 0.9182 - val_accuracy: 0.6774
# Epoch 14/100
# 6/6 [==============================] - 1s 86ms/step - loss: 1.1092 - accuracy: 0.6183 - val_loss: 0.9333 - val_accuracy: 0.7258
# Epoch 15/100
# 6/6 [==============================] - 1s 86ms/step - loss: 1.0515 - accuracy: 0.6331 - val_loss: 0.8497 - val_accuracy: 0.6935
# Epoch 16/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.9908 - accuracy: 0.6411 - val_loss: 0.8376 - val_accuracy: 0.7634
# Epoch 17/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.9574 - accuracy: 0.6626 - val_loss: 0.7584 - val_accuracy: 0.7742
# Epoch 18/100
# 6/6 [==============================] - 0s 85ms/step - loss: 0.8980 - accuracy: 0.6815 - val_loss: 0.7148 - val_accuracy: 0.8172
# Epoch 19/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.8632 - accuracy: 0.6801 - val_loss: 0.6888 - val_accuracy: 0.8011
# Epoch 20/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.8109 - accuracy: 0.7204 - val_loss: 0.6488 - val_accuracy: 0.8065
# Epoch 21/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.7548 - accuracy: 0.7204 - val_loss: 0.6390 - val_accuracy: 0.8226
# Epoch 22/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.7437 - accuracy: 0.7218 - val_loss: 0.6465 - val_accuracy: 0.7903
# Epoch 23/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.6931 - accuracy: 0.7419 - val_loss: 0.6061 - val_accuracy: 0.8333
# Epoch 24/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.6954 - accuracy: 0.7500 - val_loss: 0.6055 - val_accuracy: 0.8280
# Epoch 25/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.6726 - accuracy: 0.7473 - val_loss: 0.5926 - val_accuracy: 0.8118
# Epoch 26/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.6322 - accuracy: 0.7608 - val_loss: 0.5479 - val_accuracy: 0.8333
# Epoch 27/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.6372 - accuracy: 0.7540 - val_loss: 0.5827 - val_accuracy: 0.8065
# Epoch 28/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5945 - accuracy: 0.7634 - val_loss: 0.5379 - val_accuracy: 0.8280
# Epoch 29/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.5485 - accuracy: 0.7970 - val_loss: 0.5600 - val_accuracy: 0.8441
# Epoch 30/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5090 - accuracy: 0.8065 - val_loss: 0.5534 - val_accuracy: 0.8387
# Epoch 31/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.5094 - accuracy: 0.8199 - val_loss: 0.5054 - val_accuracy: 0.8548
# Epoch 32/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.5203 - accuracy: 0.8038 - val_loss: 0.5163 - val_accuracy: 0.8280
# Epoch 33/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.4744 - accuracy: 0.8239 - val_loss: 0.5227 - val_accuracy: 0.8333
# Epoch 34/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.4671 - accuracy: 0.8266 - val_loss: 0.5188 - val_accuracy: 0.8226
# Epoch 35/100
# 6/6 [==============================] - 0s 82ms/step - loss: 0.4874 - accuracy: 0.8185 - val_loss: 0.5263 - val_accuracy: 0.8333
# Epoch 36/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.4746 - accuracy: 0.8226 - val_loss: 0.5150 - val_accuracy: 0.8333
# Epoch 37/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.4059 - accuracy: 0.8481 - val_loss: 0.4800 - val_accuracy: 0.8548
# Epoch 38/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.4184 - accuracy: 0.8468 - val_loss: 0.4986 - val_accuracy: 0.8387
# Epoch 39/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.4248 - accuracy: 0.8508 - val_loss: 0.4968 - val_accuracy: 0.8495
# Epoch 40/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.4466 - accuracy: 0.8347 - val_loss: 0.4919 - val_accuracy: 0.8441
# Epoch 41/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.4235 - accuracy: 0.8387 - val_loss: 0.5019 - val_accuracy: 0.8441
# Epoch 42/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.3902 - accuracy: 0.8575 - val_loss: 0.4536 - val_accuracy: 0.8656
# Epoch 43/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.3693 - accuracy: 0.8642 - val_loss: 0.4685 - val_accuracy: 0.8387
# Epoch 44/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.3843 - accuracy: 0.8616 - val_loss: 0.4662 - val_accuracy: 0.8495
# Epoch 45/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.3714 - accuracy: 0.8737 - val_loss: 0.4488 - val_accuracy: 0.8710
# Epoch 46/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.3386 - accuracy: 0.8790 - val_loss: 0.4577 - val_accuracy: 0.8548
# Epoch 47/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.3153 - accuracy: 0.8790 - val_loss: 0.4449 - val_accuracy: 0.8656
# Epoch 48/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.2913 - accuracy: 0.8952 - val_loss: 0.4116 - val_accuracy: 0.8925
# Epoch 49/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.2758 - accuracy: 0.8978 - val_loss: 0.4307 - val_accuracy: 0.8656
# Epoch 50/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.3057 - accuracy: 0.8790 - val_loss: 0.4614 - val_accuracy: 0.8387
# Epoch 51/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.3083 - accuracy: 0.8710 - val_loss: 0.4359 - val_accuracy: 0.8763
# Epoch 52/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.2630 - accuracy: 0.9059 - val_loss: 0.4503 - val_accuracy: 0.8656
# Epoch 53/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.2581 - accuracy: 0.8978 - val_loss: 0.4956 - val_accuracy: 0.8495
# Epoch 54/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.2667 - accuracy: 0.9153 - val_loss: 0.4656 - val_accuracy: 0.8710
# Epoch 55/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.2828 - accuracy: 0.8965 - val_loss: 0.4382 - val_accuracy: 0.8817
# Epoch 56/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.2595 - accuracy: 0.9059 - val_loss: 0.4417 - val_accuracy: 0.8387
# Epoch 57/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.2628 - accuracy: 0.8925 - val_loss: 0.4667 - val_accuracy: 0.8441
# Epoch 58/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.2576 - accuracy: 0.9086 - val_loss: 0.5084 - val_accuracy: 0.8548
# Epoch 59/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.2312 - accuracy: 0.9207 - val_loss: 0.4485 - val_accuracy: 0.8602
# Epoch 60/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.2527 - accuracy: 0.9059 - val_loss: 0.4519 - val_accuracy: 0.8602
# Epoch 61/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.2221 - accuracy: 0.9113 - val_loss: 0.4798 - val_accuracy: 0.8656
# Epoch 62/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.2197 - accuracy: 0.9126 - val_loss: 0.4526 - val_accuracy: 0.8710
# Epoch 63/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.2034 - accuracy: 0.9220 - val_loss: 0.4571 - val_accuracy: 0.8710
# Epoch 64/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.1716 - accuracy: 0.9395 - val_loss: 0.4297 - val_accuracy: 0.8871
# Epoch 65/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.1971 - accuracy: 0.9301 - val_loss: 0.4612 - val_accuracy: 0.8817
# Epoch 66/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.1777 - accuracy: 0.9382 - val_loss: 0.4445 - val_accuracy: 0.8871
# Epoch 67/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.1904 - accuracy: 0.9261 - val_loss: 0.4666 - val_accuracy: 0.8763
# Epoch 68/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.2290 - accuracy: 0.9099 - val_loss: 0.4694 - val_accuracy: 0.8495
# Epoch 69/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.1907 - accuracy: 0.9382 - val_loss: 0.4559 - val_accuracy: 0.8817
# Epoch 70/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.1691 - accuracy: 0.9382 - val_loss: 0.4805 - val_accuracy: 0.8763
# Epoch 71/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.1639 - accuracy: 0.9435 - val_loss: 0.4375 - val_accuracy: 0.8871
# Epoch 72/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.1662 - accuracy: 0.9382 - val_loss: 0.4523 - val_accuracy: 0.9032
# Epoch 73/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.1782 - accuracy: 0.9395 - val_loss: 0.4454 - val_accuracy: 0.8656
# Epoch 74/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.1460 - accuracy: 0.9409 - val_loss: 0.4650 - val_accuracy: 0.8871
# Epoch 75/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.1434 - accuracy: 0.9422 - val_loss: 0.4909 - val_accuracy: 0.8763
# Epoch 76/100
# 6/6 [==============================] - 1s 84ms/step - loss: 0.1509 - accuracy: 0.9556 - val_loss: 0.4678 - val_accuracy: 0.8710
# Epoch 77/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.1584 - accuracy: 0.9449 - val_loss: 0.4811 - val_accuracy: 0.8871
# Epoch 78/100
# 6/6 [==============================] - 1s 86ms/step - loss: 0.1464 - accuracy: 0.9462 - val_loss: 0.4896 - val_accuracy: 0.8710
# Epoch 79/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.1177 - accuracy: 0.9583 - val_loss: 0.4733 - val_accuracy: 0.8710
# Epoch 80/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.1123 - accuracy: 0.9677 - val_loss: 0.4757 - val_accuracy: 0.8656
# Epoch 81/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.1552 - accuracy: 0.9435 - val_loss: 0.4632 - val_accuracy: 0.9032
# Epoch 82/100
# 6/6 [==============================] - 1s 85ms/step - loss: 0.1248 - accuracy: 0.9489 - val_loss: 0.4557 - val_accuracy: 0.8817
# Epoch 83/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.1311 - accuracy: 0.9556 - val_loss: 0.4761 - val_accuracy: 0.8817
# Epoch 84/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.1187 - accuracy: 0.9556 - val_loss: 0.4971 - val_accuracy: 0.8871
# Epoch 85/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.1236 - accuracy: 0.9583 - val_loss: 0.4747 - val_accuracy: 0.8817
# Epoch 86/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.1223 - accuracy: 0.9489 - val_loss: 0.4712 - val_accuracy: 0.8710
# Epoch 87/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.1135 - accuracy: 0.9556 - val_loss: 0.5031 - val_accuracy: 0.9032
# Epoch 88/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.1214 - accuracy: 0.9610 - val_loss: 0.4648 - val_accuracy: 0.8656
# Epoch 89/100
# 6/6 [==============================] - 1s 89ms/step - loss: 0.1474 - accuracy: 0.9462 - val_loss: 0.4671 - val_accuracy: 0.8871
# Epoch 90/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.1121 - accuracy: 0.9583 - val_loss: 0.4607 - val_accuracy: 0.8925
# Epoch 91/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.1218 - accuracy: 0.9516 - val_loss: 0.4862 - val_accuracy: 0.8871
# Epoch 92/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.0997 - accuracy: 0.9624 - val_loss: 0.4666 - val_accuracy: 0.8871
# Epoch 93/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.0943 - accuracy: 0.9664 - val_loss: 0.5033 - val_accuracy: 0.8871
# Epoch 94/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.0747 - accuracy: 0.9772 - val_loss: 0.4883 - val_accuracy: 0.8602
# Epoch 95/100
# 6/6 [==============================] - 1s 87ms/step - loss: 0.0857 - accuracy: 0.9718 - val_loss: 0.4703 - val_accuracy: 0.8978
# Epoch 96/100
# 6/6 [==============================] - 0s 84ms/step - loss: 0.0759 - accuracy: 0.9812 - val_loss: 0.4836 - val_accuracy: 0.8817
# Epoch 97/100
# 6/6 [==============================] - 1s 91ms/step - loss: 0.0804 - accuracy: 0.9731 - val_loss: 0.4843 - val_accuracy: 0.8710
# Epoch 98/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.0777 - accuracy: 0.9704 - val_loss: 0.4906 - val_accuracy: 0.8871
# Epoch 99/100
# 6/6 [==============================] - 1s 90ms/step - loss: 0.1046 - accuracy: 0.9543 - val_loss: 0.5026 - val_accuracy: 0.8710
# Epoch 100/100
# 6/6 [==============================] - 0s 83ms/step - loss: 0.0826 - accuracy: 0.9691 - val_loss: 0.5101 - val_accuracy: 0.8871
# 6/6 [==============================] - 0s 12ms/step
#
# Predictions:
#      predictedValues
# 0           anxiety
# 1           anxiety
# 2           boredom
# 3           neutral
# 4           boredom
# ..              ...
# 181         neutral
# 182         neutral
# 183         sadness
# 184         boredom
# 185         sadness
#
# [186 rows x 1 columns]
# Model Accuracy: 0.8870967741935484
# Conf Matrix:
#  [[ 10   0   0   0   0   1   0]
#  [  0  11   0   0   0   2   0]
#  [  0   0   7   1   0   1   0]
#  [  0   0   0  12   1   0   0]
#  [  0   0   0   2   7   0   0]
#  [  0   1   1   0   2 114   3]
#  [  0   1   0   0   0   5   4]]
#               precision    recall  f1-score   support
#
#      anxiety       1.00      0.91      0.95        11
#      boredom       0.85      0.85      0.85        13
#      disgust       0.88      0.78      0.82         9
#        happy       0.80      0.92      0.86        13
#    hot anger       0.70      0.78      0.74         9
#      neutral       0.93      0.94      0.93       121
#      sadness       0.57      0.40      0.47        10
#
#     accuracy                           0.89       186
#    macro avg       0.82      0.80      0.80       186
# weighted avg       0.88      0.89      0.88       186
#
# results\LDC_male_10-18-2023-15-08-51\LDC_male-iter-4-cnnHistory.png
# IO Log - Saved trained model at results\LDC_male_10-18-2023-15-08-51\LDC_male-iter-4\LDC_male-iter-4.h5
# Run Summary:
# Min: 0.8172043010752689
# Max: 0.8870967741935484
# Mean: 0.843010752688172
# 30/30 [==============================] - 0s 9ms/step
